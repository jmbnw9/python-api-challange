# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %%
#URL for the Weather Map API call 
units = "imperial"
url1 = "http://api.openweathermap.org/data/2.5/weather?"
samplecity = "bowling green"
url = f"{url1}appid={weather_api_key}&units={units}&q="
response = requests.get(url+samplecity).json()
response
# Out:
# {'coord': {'lon': -86.44, 'lat': 36.99},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 40.46,
#   'feels_like': 29.32,
#   'temp_min': 39.2,
#   'temp_max': 42.01,
#   'pressure': 1022,
#   'humidity': 64},
#  'visibility': 10000,
#  'wind': {'speed': 12.75, 'deg': 80},
#  'clouds': {'all': 1},
#  'dt': 1608059490,
#  'sys': {'type': 1,
#   'id': 3529,
#   'country': 'US',
#   'sunrise': 1608036732,
#   'sunset': 1608071418},
#  'timezone': -21600,
#  'id': 4285268,
#  'name': 'Bowling Green',
#  'cod': 200}

# %%
# Create an empty list to store the responses
units = "imperial"
url = f"{url1}appid={weather_api_key}&units={units}&q="
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#Call Counter
record = 1

#Print this statement
print(f"Beginning Data Retrieval")
print(f"---------------------------")

# Make a request to loop through the cities
for city in cities:
    try:
        response = requests.get(url+city).json()         
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record: {record} | {city}")
    
        #Keep increasing counter by 1
        record = record + 1

        #if there is no record found, skip to the next
    except:
    
        print(f"City not found")
    
    continue
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record: 1 | port elizabeth
# Processing Record: 2 | cabo san lucas
# Processing Record: 3 | lebu
# Processing Record: 4 | bredasdorp
# City not found
# Processing Record: 5 | noshiro
# Processing Record: 6 | dikson
# Processing Record: 7 | cozumel
# Processing Record: 8 | jamestown
# Processing Record: 9 | namibe
# Processing Record: 10 | hobart
# Processing Record: 11 | hilo
# Processing Record: 12 | kapaa
# Processing Record: 13 | nikolskoye
# Processing Record: 14 | oranjemund
# Processing Record: 15 | mogzon
# Processing Record: 16 | fort morgan
# Processing Record: 17 | barcelos
# Processing Record: 18 | sur
# Processing Record: 19 | bandarbeyla
# Processing Record: 20 | barrow
# Processing Record: 21 | new norfolk
# Processing Record: 22 | ostrovnoy
# Processing Record: 23 | alofi
# Processing Record: 24 | borogontsy
# Processing Record: 25 | albany
# Processing Record: 26 | ust-omchug
# ...

# %%
#create a dictonary to set up the dataframe
weather_dict = {"City":city_name, "Lat":lat,"Lng":lng, "Max Temp":max_temp, "Humidity":humidity, "Cloudiness":cloudiness, "Wind Speed":wind_speed, "Country":country,"Date":date}

#create the datae frame and output to a csv
weather_data = pd.DataFrame(weather_dict)

weather_data.to_csv("output_data.csv")

weather_data
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Elizabeth -33.92   25.57     68.00        82           0
# 1    Cabo San Lucas  22.89 -109.91     75.00        60          20
# 2              Lebu -37.62  -73.65     56.53        59           0
# 3        Bredasdorp -34.53   20.04     60.80        67           0
# 4           Noshiro  40.20  140.02     28.96        89          99
# ..              ...    ...     ...       ...       ...         ...
# 541       Mogadishu   2.04   45.34     77.56        79           0
# 542       Ulladulla -35.35  150.47     70.00       100          90
# 543      Lubumbashi -11.66   27.48     64.47        94         100
# 544         Manggar  -2.88  108.27     80.15        81         100
# 545        Kankakee  41.15  -87.87     32.00        80           1
#
#      Wind Speed Country        Date
# 0         13.87      ZA  1608059557
# 1          3.36      MX  1608059391
# 2         23.44      CL  1608059429
# ...

# %%
#check to see if there are any cities with humidity greater than 100%
new_weather_data = weather_data.loc[weather_data["Humidity"]>100]
new_weather_data
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#Using a scatter plot compare latitude vs. temp
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker ="o")
            
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")

#save the plot as .pngs
plt.savefig("figure1.png")
            
plt.show()

# %%
#Using a scatter plot compare latitude vs. humidity
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker ="o")
            
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidty (%)")

#save the plot as .pngs
plt.savefig("figure2.png")
            
plt.show()

# %%
#Using a scatter plot compare latitude vs. cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")
            
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#save the plot as .pngs
plt.savefig("figure3.png")
            
plt.show()

# %%
#Using a scatter plot compare latitude vs. wind speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")
            
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#save the plot as .pngs
plt.savefig("figure4.png")
            
plt.show()

# %%
#create a dataframe for just the northern hemisphere
northern_weather_data = weather_data.loc[weather_data["Lat"]>=0]
northern_weather_data
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Bowling Green  36.99  -86.44      2.00        74          90        3.10
# 3            Arlit  18.74    7.39     24.29        15           0        2.69
# 8           Albany  42.60  -73.97      1.67        81         100        0.75
# 9        Blagoyevo  63.37   47.92     -9.94        97          98        1.70
# 11           Korla  41.76   86.15     -7.41        87           6        1.26
# ..             ...    ...     ...       ...       ...         ...         ...
# 538    Shubarkuduk  49.14   56.49     -9.12        86         100        2.86
# 539      Vincennes  48.85    2.43     12.22        81          90        3.60
# 540      Barcelona  41.39    2.16     14.44        93          75        1.50
# 541      Sept-Îles  50.20  -66.38     -1.67        86          92        2.10
# 542    Songjianghe  42.19  127.48    -19.29        80         100        3.79
#
#     Country        Date
# ...

# %%
#create a dataframe for just the southern hemisphere
southern_weather_data = weather_data.loc[weather_data["Lat"]<0]
southern_weather_data
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1    Puerto Ayora  -0.74  -90.35     28.00        58          20        8.20
# 2           Vaini -21.20 -175.20     23.00       100          90        4.60
# 4           Moree -29.47  149.85     20.00        68          40        3.60
# 5         Mataura -46.19  168.86     12.22        84          13        6.26
# 6       Cape Town -33.93   18.42     19.44        77          20        4.60
# ..            ...    ...     ...       ...       ...         ...         ...
# 520         Pilar  -9.60  -35.96     29.00        58          20        5.70
# 527        Kawalu  -7.38  108.21     22.74        92         100        0.52
# 529   Te Kauwhata -37.40  175.15     16.11        87         100        1.50
# 537  Port Augusta -32.50  137.77     20.00        82          90        5.10
# 543        Uruçuí  -7.23  -44.56     34.48        36          63        2.69
#
#     Country        Date
# ...

# %%
#set up to create the linear regressions
def linearplot(x_values, y_values, y_label, cord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,cord,fontsize=15,color="red")
    plt.xlabel('Lat')
    plt.ylabel(y_label)
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
#find the linear regression for max temp vs latitude in northern hemisphere
x_values = northern_weather_data["Lat"]
y_values = northern_weather_data["Max Temp"]
y_label = "Max Temp"
cord = (60, 20)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure5.png")
# Out:
# The r-squared is: 0.6749810145366134

# %%
#find the linear regression for max temp vs latitude in southern hemisphere
x_values = southern_weather_data["Lat"]
y_values = southern_weather_data["Max Temp"]
y_label = "Max Temp"
cord = (-20, 10)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure6.png")
# Out:
# The r-squared is: 0.44787910604200587

# %%
#find the linear regression for humidity vs latitude in northern hemisphere
x_values = northern_weather_data["Lat"]
y_values = northern_weather_data["Humidity"]
y_label = "Humidity"
cord = (60, 20)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure7.png")
# Out:
# The r-squared is: 0.16109638653350924

# %%
#find the linear regression for humidity vs latitude in southern hemisphere
x_values = southern_weather_data["Lat"]
y_values = southern_weather_data["Humidity"]
y_label = "Humidity"
cord = (-20,20)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure8.png")
# Out:
# The r-squared is: 0.02673186663559201

# %%
#find the linear regression for cloudiness vs latitude in northern hemisphere
x_values = northern_weather_data["Lat"]
y_values = northern_weather_data["Cloudiness"]
y_label = "Cloudiness"
cord = (60, 20)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure9.png")
# Out:
# The r-squared is: 0.09083113327887506

# %%
#find the linear regression for cloudiness vs latitude in southern hemisphere
x_values = southern_weather_data["Lat"]
y_values = southern_weather_data["Cloudiness"]
y_label = "Cloudiness"
cord = (-50,60)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure10.png")
# Out:
# The r-squared is: 0.11605525310620719

# %%
#find the linear regression for wind speed vs latitude in northern hemisphere
x_values = northern_weather_data["Lat"]
y_values = northern_weather_data["Wind Speed"]
y_label = "Wind Speed(mph)"
cord = (0,15.0)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure11.png")
# Out:
# The r-squared is: 0.015249942895537855

# %%
#find the linear regression for wind speed vs latitude in southern hemisphere
x_values = southern_weather_data["Lat"]
y_values = southern_weather_data["Wind Speed"]
y_label = "Wind Speed(mph)"
cord = (-20,14)
linearplot(x_values, y_values, y_label, cord)
plt.savefig("figure12.png")
# Out:
# The r-squared is: 0.03923848726863418
