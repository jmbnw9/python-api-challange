# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities[:2]
# Out:
# ['bowling green', 'puerto ayora']

# %%
#URL for the Weather Map API call 
url1 = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
samplecity = "bowling green"
url = f"{url1}appid={weather_api_key}&units={units}&q="
response = requests.get(url+samplecity).json()
response
# Out:
# {'coord': {'lon': -86.44, 'lat': 36.99},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 2,
#   'feels_like': -2.8,
#   'temp_min': 2,
#   'temp_max': 2,
#   'pressure': 1024,
#   'humidity': 74},
#  'visibility': 10000,
#  'wind': {'speed': 3.6, 'deg': 320, 'gust': 7.2},
#  'clouds': {'all': 90},
#  'dt': 1607973254,
#  'sys': {'type': 1,
#   'id': 3529,
#   'country': 'US',
#   'sunrise': 1607950293,
#   'sunset': 1607985001},
#  'timezone': -21600,
#  'id': 4285268,
#  'name': 'Bowling Green',
#  'cod': 200}

# %%
# Create an empty list to store the responses
url = f"{url1}appid={weather_api_key}&units={units}&q="
units = "imperial"

city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#Call Counter
record = 1

#Print this statement
print(f"Beginning Data Retrieval")
print(f"---------------------------")

# Make a request to loop through the cities
for city in cities:
    try:
        response = requests.get(url+city).json()         
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record: {record} | {city}")
    
        #Keep increasing counter by 1
        record = record + 1

        #if there is no record found, skip to the next
    except:
    
        print(f"City not found")
    
    continue
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record: 1 | bowling green
# Processing Record: 2 | puerto ayora
# Processing Record: 3 | vaini
# Processing Record: 4 | arlit
# Processing Record: 5 | moree
# Processing Record: 6 | mataura
# Processing Record: 7 | cape town
# Processing Record: 8 | saint-pierre
# Processing Record: 9 | albany
# Processing Record: 10 | blagoyevo
# Processing Record: 11 | busselton
# Processing Record: 12 | korla
# City not found
# Processing Record: 13 | cayenne
# City not found
# Processing Record: 14 | ancud
# Processing Record: 15 | hay river
# Processing Record: 16 | oneonta
# Processing Record: 17 | brooks
# Processing Record: 18 | cidreira
# Processing Record: 19 | sistranda
# Processing Record: 20 | poya
# City not found
# Processing Record: 21 | comacchio
# City not found
# Processing Record: 22 | los llanos de aridane
# Processing Record: 23 | fort nelson
# Processing Record: 24 | alacranes
# Processing Record: 25 | punta arenas
# Processing Record: 26 | tuktoyaktuk
# Processing Record: 27 | saint-philippe
# Processing Record: 28 | san quintin
# Processing Record: 29 | ati
# Processing Record: 30 | tuatapere
# Processing Record: 31 | pacific grove
# Processing Record: 32 | hirara
# Processing Record: 33 | atuona
# Processing Record: 34 | beloha
# Processing Record: 35 | svetlogorsk
# Processing Record: 36 | westport
# Processing Record: 37 | hermanus
# Processing Record: 38 | nador
# Processing Record: 39 | east london
# Processing Record: 40 | carnarvon
# Processing Record: 41 | bennington
# Processing Record: 42 | hobart
# Processing Record: 43 | broken hill
# Processing Record: 44 | kirakira
# Processing Record: 45 | yuli
# Processing Record: 46 | hithadhoo
# Processing Record: 47 | isangel
# City not found
# Processing Record: 48 | rikitea
# Processing Record: 49 | matagami
# Processing Record: 50 | ribeira grande
# Processing Record: 51 | grand gaube
# Processing Record: 52 | yar-sale
# Processing Record: 53 | derzhavinsk
# Processing Record: 54 | aiken
# Processing Record: 55 | dikson
# Processing Record: 56 | cabedelo
# Processing Record: 57 | ushuaia
# City not found
# Processing Record: 58 | codrington
# Processing Record: 59 | butaritari
# Processing Record: 60 | urumqi
# Processing Record: 61 | barrow
# Processing Record: 62 | sola
# Processing Record: 63 | longyearbyen
# Processing Record: 64 | lompoc
# City not found
# Processing Record: 65 | iqaluit
# Processing Record: 66 | gidole
# Processing Record: 67 | gboko
# Processing Record: 68 | makat
# Processing Record: 69 | kapaa
# Processing Record: 70 | itarema
# Processing Record: 71 | lasa
# Processing Record: 72 | torbay
# Processing Record: 73 | klaksvik
# Processing Record: 74 | bengkulu
# Processing Record: 75 | hammerfest
# Processing Record: 76 | kaitangata
# Processing Record: 77 | butembo
# Processing Record: 78 | grand island
# Processing Record: 79 | san rafael
# Processing Record: 80 | perth
# Processing Record: 81 | jamestown
# Processing Record: 82 | brae
# Processing Record: 83 | pasvalys
# Processing Record: 84 | honiara
# Processing Record: 85 | bowen
# Processing Record: 86 | airai
# Processing Record: 87 | tutoia
# Processing Record: 88 | norman wells
# Processing Record: 89 | saint george
# Processing Record: 90 | nantucket
# Processing Record: 91 | bredasdorp
# Processing Record: 92 | nikolskoye
# Processing Record: 93 | bethel
# Processing Record: 94 | taketa
# Processing Record: 95 | sinnamary
# City not found
# Processing Record: 96 | constantine
# Processing Record: 97 | mufulira
# Processing Record: 98 | castro
# Processing Record: 99 | safford
# City not found
# Processing Record: 100 | chuy
# Processing Record: 101 | ha giang
# City not found
# Processing Record: 102 | wagar
# Processing Record: 103 | dingle
# Processing Record: 104 | lorengau
# Processing Record: 105 | carballo
# Processing Record: 106 | qaanaaq
# City not found
# Processing Record: 107 | lebu
# City not found
# Processing Record: 108 | katsuura
# Processing Record: 109 | kidal
# City not found
# Processing Record: 110 | fort-shevchenko
# Processing Record: 111 | kazanskaya
# Processing Record: 112 | walvis bay
# Processing Record: 113 | ostrovnoy
# Processing Record: 114 | sao filipe
# Processing Record: 115 | devils lake
# Processing Record: 116 | hilton head island
# Processing Record: 117 | victoria
# Processing Record: 118 | adrar
# Processing Record: 119 | omboue
# Processing Record: 120 | broome
# Processing Record: 121 | gao
# Processing Record: 122 | rudsar
# Processing Record: 123 | souillac
# Processing Record: 124 | tijara
# Processing Record: 125 | berlevag
# Processing Record: 126 | tiksi
# Processing Record: 127 | paijan
# Processing Record: 128 | fenoarivo
# Processing Record: 129 | ugoofaaru
# Processing Record: 130 | port blair
# Processing Record: 131 | coquimbo
# Processing Record: 132 | kodiak
# Processing Record: 133 | faanui
# City not found
# Processing Record: 134 | thompson
# Processing Record: 135 | yellowknife
# Processing Record: 136 | tubuala
# Processing Record: 137 | baft
# Processing Record: 138 | kudahuvadhoo
# Processing Record: 139 | olavarria
# Processing Record: 140 | zambrano
# Processing Record: 141 | clyde river
# Processing Record: 142 | maniitsoq
# Processing Record: 143 | mulchen
# Processing Record: 144 | avarua
# Processing Record: 145 | chulman
# Processing Record: 146 | new norfolk
# Processing Record: 147 | chokurdakh
# Processing Record: 148 | narsaq
# Processing Record: 149 | aanekoski
# Processing Record: 150 | ilulissat
# Processing Record: 151 | moose factory
# City not found
# Processing Record: 152 | flin flon
# Processing Record: 153 | touros
# Processing Record: 154 | bathsheba
# Processing Record: 155 | padang
# Processing Record: 156 | pevek
# Processing Record: 157 | georgetown
# Processing Record: 158 | khatanga
# Processing Record: 159 | tura
# Processing Record: 160 | vardo
# Processing Record: 161 | provideniya
# Processing Record: 162 | vertientes
# Processing Record: 163 | cabo san lucas
# Processing Record: 164 | yuancheng
# Processing Record: 165 | zyryanovsk
# Processing Record: 166 | sitka
# Processing Record: 167 | najran
# Processing Record: 168 | aklavik
# Processing Record: 169 | deputatskiy
# Processing Record: 170 | atasu
# City not found
# Processing Record: 171 | kavieng
# Processing Record: 172 | almaznyy
# Processing Record: 173 | pahrump
# Processing Record: 174 | chara
# Processing Record: 175 | manadhoo
# Processing Record: 176 | acapulco
# Processing Record: 177 | tasiilaq
# Processing Record: 178 | schiffdorf
# Processing Record: 179 | lloret de mar
# Processing Record: 180 | lewiston
# Processing Record: 181 | vostok
# Processing Record: 182 | sarakhs
# City not found
# Processing Record: 183 | harlingen
# Processing Record: 184 | alugan
# Processing Record: 185 | trairi
# Processing Record: 186 | les cayes
# Processing Record: 187 | hilo
# Processing Record: 188 | berezniki
# Processing Record: 189 | qasigiannguit
# Processing Record: 190 | aviles
# Processing Record: 191 | upernavik
# Processing Record: 192 | bonavista
# Processing Record: 193 | esperance
# Processing Record: 194 | kyren
# Processing Record: 195 | kahului
# Processing Record: 196 | boddam
# Processing Record: 197 | oistins
# Processing Record: 198 | nhulunbuy
# Processing Record: 199 | chapayevka
# Processing Record: 200 | port hawkesbury
# Processing Record: 201 | lere
# Processing Record: 202 | zhigansk
# Processing Record: 203 | santa cruz
# Processing Record: 204 | udachnyy
# Processing Record: 205 | mkushi
# Processing Record: 206 | husavik
# Processing Record: 207 | mar del plata
# Processing Record: 208 | cascais
# Processing Record: 209 | cherskiy
# City not found
# Processing Record: 210 | port alfred
# Processing Record: 211 | severo-kurilsk
# Processing Record: 212 | avera
# Processing Record: 213 | shirvan
# Processing Record: 214 | cavalcante
# Processing Record: 215 | olafsvik
# Processing Record: 216 | bluff
# Processing Record: 217 | taitung
# Processing Record: 218 | valparaiso
# Processing Record: 219 | arona
# Processing Record: 220 | mogadishu
# Processing Record: 221 | nishihara
# Processing Record: 222 | flinders
# Processing Record: 223 | hami
# Processing Record: 224 | fuyu
# Processing Record: 225 | lenger
# Processing Record: 226 | kars
# Processing Record: 227 | bilibino
# Processing Record: 228 | tocopilla
# Processing Record: 229 | abu dhabi
# Processing Record: 230 | pike creek
# Processing Record: 231 | port-cartier
# Processing Record: 232 | marawi
# Processing Record: 233 | svetlyy
# Processing Record: 234 | kaseda
# Processing Record: 235 | arraial do cabo
# Processing Record: 236 | manga
# Processing Record: 237 | iraquara
# Processing Record: 238 | nenagh
# Processing Record: 239 | leningradskiy
# Processing Record: 240 | mount isa
# Processing Record: 241 | the valley
# Processing Record: 242 | ponta do sol
# Processing Record: 243 | abu zabad
# Processing Record: 244 | geraldton
# Processing Record: 245 | matara
# Processing Record: 246 | ust-koksa
# Processing Record: 247 | bandarbeyla
# Processing Record: 248 | ucluelet
# City not found
# Processing Record: 249 | kingman
# Processing Record: 250 | sabang
# Processing Record: 251 | aswan
# Processing Record: 252 | obidos
# Processing Record: 253 | cockburn town
# Processing Record: 254 | poum
# Processing Record: 255 | saskylakh
# Processing Record: 256 | afyonkarahisar
# Processing Record: 257 | kavaratti
# Processing Record: 258 | mahebourg
# Processing Record: 259 | hasaki
# Processing Record: 260 | ust-kuyga
# Processing Record: 261 | gigmoto
# Processing Record: 262 | coihaique
# Processing Record: 263 | vestmannaeyjar
# Processing Record: 264 | vila franca do campo
# Processing Record: 265 | san cristobal
# Processing Record: 266 | lundazi
# City not found
# Processing Record: 267 | launceston
# Processing Record: 268 | bose
# Processing Record: 269 | pangnirtung
# City not found
# Processing Record: 270 | seoul
# Processing Record: 271 | bourail
# Processing Record: 272 | dawson creek
# Processing Record: 273 | hamilton
# City not found
# Processing Record: 274 | oum hadjer
# Processing Record: 275 | samoded
# City not found
# Processing Record: 276 | lagoa
# Processing Record: 277 | rudnogorsk
# City not found
# Processing Record: 278 | awbari
# City not found
# City not found
# Processing Record: 279 | rosehearty
# Processing Record: 280 | wattegama
# Processing Record: 281 | mangrol
# City not found
# Processing Record: 282 | saint anthony
# Processing Record: 283 | saldanha
# Processing Record: 284 | ajdabiya
# Processing Record: 285 | ormara
# Processing Record: 286 | chiapilla
# Processing Record: 287 | jalingo
# Processing Record: 288 | ixtapa
# Processing Record: 289 | westlock
# Processing Record: 290 | jalu
# Processing Record: 291 | melilla
# Processing Record: 292 | modasa
# Processing Record: 293 | kindu
# Processing Record: 294 | buala
# Processing Record: 295 | alyangula
# Processing Record: 296 | teya
# Processing Record: 297 | yumen
# Processing Record: 298 | sandy bay
# Processing Record: 299 | port-gentil
# Processing Record: 300 | half moon bay
# Processing Record: 301 | dubbo
# Processing Record: 302 | biltine
# Processing Record: 303 | te anau
# Processing Record: 304 | harper
# Processing Record: 305 | pinega
# Processing Record: 306 | hofn
# Processing Record: 307 | mayumba
# Processing Record: 308 | emerald
# Processing Record: 309 | lamar
# City not found
# Processing Record: 310 | marneuli
# Processing Record: 311 | dali
# Processing Record: 312 | songkhla
# Processing Record: 313 | port lincoln
# Processing Record: 314 | kununurra
# Processing Record: 315 | batemans bay
# Processing Record: 316 | fortuna
# City not found
# Processing Record: 317 | phan thiet
# Processing Record: 318 | elat
# Processing Record: 319 | tahta
# Processing Record: 320 | tottori
# Processing Record: 321 | evensk
# City not found
# Processing Record: 322 | san angelo
# Processing Record: 323 | waipawa
# Processing Record: 324 | ossora
# Processing Record: 325 | nerchinsk
# Processing Record: 326 | bako
# Processing Record: 327 | tezu
# Processing Record: 328 | esso
# Processing Record: 329 | lavrentiya
# Processing Record: 330 | viedma
# Processing Record: 331 | moranbah
# City not found
# Processing Record: 332 | ketchikan
# Processing Record: 333 | talaya
# Processing Record: 334 | banda aceh
# Processing Record: 335 | raudeberg
# Processing Record: 336 | surgut
# Processing Record: 337 | zasechnoye
# Processing Record: 338 | gurupa
# Processing Record: 339 | la asuncion
# Processing Record: 340 | itacarambi
# City not found
# Processing Record: 341 | rio grande
# Processing Record: 342 | farah
# Processing Record: 343 | tokur
# Processing Record: 344 | bantou
# Processing Record: 345 | faya
# Processing Record: 346 | salinas
# Processing Record: 347 | asau
# Processing Record: 348 | bud
# Processing Record: 349 | okha
# Processing Record: 350 | lar
# Processing Record: 351 | xining
# Processing Record: 352 | monrovia
# Processing Record: 353 | marfino
# Processing Record: 354 | garwa
# Processing Record: 355 | maues
# Processing Record: 356 | yeppoon
# Processing Record: 357 | lucapa
# Processing Record: 358 | uddevalla
# Processing Record: 359 | asfi
# Processing Record: 360 | egvekinot
# Processing Record: 361 | rostock
# Processing Record: 362 | whitecourt
# Processing Record: 363 | natal
# City not found
# City not found
# Processing Record: 364 | limbe
# Processing Record: 365 | surt
# Processing Record: 366 | port elizabeth
# Processing Record: 367 | lima
# City not found
# Processing Record: 368 | laguna
# Processing Record: 369 | san antonio
# City not found
# Processing Record: 370 | bambous virieux
# Processing Record: 371 | gorontalo
# Processing Record: 372 | carutapera
# Processing Record: 373 | ngunguru
# Processing Record: 374 | east bethel
# Processing Record: 375 | la ronge
# Processing Record: 376 | camana
# Processing Record: 377 | nome
# Processing Record: 378 | bafq
# Processing Record: 379 | ginir
# Processing Record: 380 | luderitz
# Processing Record: 381 | dalby
# Processing Record: 382 | kenora
# City not found
# Processing Record: 383 | melfi
# Processing Record: 384 | honningsvag
# Processing Record: 385 | la palma
# Processing Record: 386 | sao joao da barra
# Processing Record: 387 | comodoro rivadavia
# Processing Record: 388 | sungaipenuh
# Processing Record: 389 | lazaro cardenas
# Processing Record: 390 | agadez
# Processing Record: 391 | horsham
# Processing Record: 392 | tamale
# Processing Record: 393 | mujiayingzi
# Processing Record: 394 | miri
# Processing Record: 395 | razdolinsk
# Processing Record: 396 | dickson
# Processing Record: 397 | bejar
# Processing Record: 398 | moindou
# Processing Record: 399 | windhoek
# Processing Record: 400 | leh
# Processing Record: 401 | muborak
# Processing Record: 402 | komsomolskiy
# Processing Record: 403 | umm lajj
# Processing Record: 404 | santona
# Processing Record: 405 | dunedin
# Processing Record: 406 | omis
# Processing Record: 407 | waynesville
# Processing Record: 408 | yerbogachen
# Processing Record: 409 | toyooka
# Processing Record: 410 | shimoda
# Processing Record: 411 | mantua
# Processing Record: 412 | nanortalik
# Processing Record: 413 | goma
# Processing Record: 414 | koumac
# Processing Record: 415 | jaumave
# Processing Record: 416 | lardos
# Processing Record: 417 | kjollefjord
# Processing Record: 418 | bagdarin
# Processing Record: 419 | hambantota
# Processing Record: 420 | kloulklubed
# Processing Record: 421 | karratha
# Processing Record: 422 | manicore
# City not found
# Processing Record: 423 | dinhata
# Processing Record: 424 | bereda
# Processing Record: 425 | port said
# Processing Record: 426 | otradnoye
# Processing Record: 427 | taoudenni
# City not found
# Processing Record: 428 | helong
# Processing Record: 429 | tyrma
# Processing Record: 430 | fort frances
# Processing Record: 431 | sulangan
# Processing Record: 432 | abu samrah
# Processing Record: 433 | labuhan
# Processing Record: 434 | palmer
# Processing Record: 435 | tigil
# Processing Record: 436 | nalut
# Processing Record: 437 | tagusao
# Processing Record: 438 | wilmington
# City not found
# Processing Record: 439 | vao
# Processing Record: 440 | tvoroyri
# Processing Record: 441 | mecca
# Processing Record: 442 | banjarmasin
# Processing Record: 443 | rocha
# Processing Record: 444 | ahipara
# Processing Record: 445 | radom
# Processing Record: 446 | nouadhibou
# Processing Record: 447 | stokmarknes
# Processing Record: 448 | ponta delgada
# Processing Record: 449 | bonanza
# Processing Record: 450 | wukari
# Processing Record: 451 | ust-ilimsk
# Processing Record: 452 | chapais
# Processing Record: 453 | lakes entrance
# Processing Record: 454 | san patricio
# Processing Record: 455 | baruun-urt
# Processing Record: 456 | yeniseysk
# Processing Record: 457 | storforshei
# Processing Record: 458 | grinnell
# Processing Record: 459 | energetik
# City not found
# Processing Record: 460 | garowe
# Processing Record: 461 | nchelenge
# Processing Record: 462 | mattru
# Processing Record: 463 | doha
# Processing Record: 464 | naze
# Processing Record: 465 | el reno
# Processing Record: 466 | kruisfontein
# Processing Record: 467 | robertson
# City not found
# Processing Record: 468 | mayor pablo lagerenza
# Processing Record: 469 | maneadero
# Processing Record: 470 | sambava
# Processing Record: 471 | langham
# Processing Record: 472 | haines junction
# Processing Record: 473 | salalah
# City not found
# Processing Record: 474 | hope
# Processing Record: 475 | antibes
# Processing Record: 476 | goderich
# Processing Record: 477 | wanning
# Processing Record: 478 | bayan
# Processing Record: 479 | cap malheureux
# City not found
# City not found
# Processing Record: 480 | capitan bado
# Processing Record: 481 | pandan
# Processing Record: 482 | bouillante
# Processing Record: 483 | chadan
# Processing Record: 484 | aranda de duero
# Processing Record: 485 | riviere-au-renard
# Processing Record: 486 | sorong
# Processing Record: 487 | lhokseumawe
# Processing Record: 488 | lieksa
# Processing Record: 489 | khani
# Processing Record: 490 | ostuni
# Processing Record: 491 | tautira
# Processing Record: 492 | liepaja
# Processing Record: 493 | helena
# Processing Record: 494 | mount gambier
# Processing Record: 495 | ramnagar
# Processing Record: 496 | samarai
# Processing Record: 497 | martapura
# Processing Record: 498 | canavieiras
# Processing Record: 499 | chiredzi
# Processing Record: 500 | aasiaat
# Processing Record: 501 | north platte
# Processing Record: 502 | aleksandrovsk-sakhalinskiy
# Processing Record: 503 | barranca
# Processing Record: 504 | gamba
# City not found
# Processing Record: 505 | college
# Processing Record: 506 | sri aman
# Processing Record: 507 | russell
# Processing Record: 508 | jiangyou
# City not found
# Processing Record: 509 | maple creek
# Processing Record: 510 | berdigestyakh
# Processing Record: 511 | ambon
# Processing Record: 512 | podbrdo
# Processing Record: 513 | yenagoa
# Processing Record: 514 | shetpe
# Processing Record: 515 | lebyazhye
# Processing Record: 516 | hobyo
# City not found
# Processing Record: 517 | ahuimanu
# Processing Record: 518 | nemuro
# Processing Record: 519 | ereymentau
# Processing Record: 520 | alofi
# Processing Record: 521 | pilar
# Processing Record: 522 | belaya gora
# Processing Record: 523 | mirabad
# Processing Record: 524 | puerto escondido
# Processing Record: 525 | gerash
# Processing Record: 526 | chalus
# City not found
# Processing Record: 527 | portland
# Processing Record: 528 | kawalu
# Processing Record: 529 | makakilo city
# Processing Record: 530 | te kauwhata
# City not found
# Processing Record: 531 | calvia
# Processing Record: 532 | haverfordwest
# Processing Record: 533 | todos santos
# City not found
# Processing Record: 534 | guadalupe y calvo
# Processing Record: 535 | krasnoarmeyskiy
# City not found
# Processing Record: 536 | yagoua
# Processing Record: 537 | kayes
# Processing Record: 538 | port augusta
# Processing Record: 539 | shubarkuduk
# Processing Record: 540 | vincennes
# Processing Record: 541 | barcelona
# Processing Record: 542 | sept-iles
# Processing Record: 543 | songjianghe
# Processing Record: 544 | urucui

# %%
weather_dict = {"City":city_name, "Lat":lat,"Lng":lng, "Max Temp":max_temp, "Humidity":humidity, "Cloudiness":cloudiness, "Wind Speed":wind_speed, "Country":country,"Date":date}

weather_data = pd.DataFrame(weather_dict)

weather_data.to_csv("output_data.csv")

weather_data
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Bowling Green  36.99  -86.44      2.00        74          90        3.10
# 1     Puerto Ayora  -0.74  -90.35     28.00        58          20        8.20
# 2            Vaini -21.20 -175.20     23.00       100          90        4.60
# 3            Arlit  18.74    7.39     24.29        15           0        2.69
# 4            Moree -29.47  149.85     20.00        68          40        3.60
# ..             ...    ...     ...       ...       ...         ...         ...
# 539      Vincennes  48.85    2.43     12.22        81          90        3.60
# 540      Barcelona  41.39    2.16     14.44        93          75        1.50
# 541      Sept-Îles  50.20  -66.38     -1.67        86          92        2.10
# 542    Songjianghe  42.19  127.48    -19.29        80         100        3.79
# 543         Uruçuí  -7.23  -44.56     34.48        36          63        2.69
#
#     Country        Date
# 0        US  1607974100
# 1        EC  1607974135
# 2        TO  1607974135
# 3        NE  1607974135
# 4        AU  1607974135
# ..      ...         ...
# 539      FR  1607973692
# 540      ES  1607973384
# 541      CA  1607973482
# 542      CN  1607973692
# 543      BR  1607973693
#
# [544 rows x 9 columns]
